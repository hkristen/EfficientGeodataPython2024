# %% [markdown]
# # Python Basics III - Exercises
# Date: 19.04.2024
# Lecturers: Harald Kristen &
# Matthias Wecht

# %% [markdown]
# ## Exercise#1 Compound Interest

# %% [markdown]
# You have 20 minutes to solve the below exercises and produce the expected outputs. One student will be choosen randomly to present his/hers results.

# %% [markdown]
#
# We will try to implement the following example from https://de.wikipedia.org/wiki/Zinseszins
#
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# Let's build a function that does basics compound interest (=Zinseszins) math. The user *should be able to choose to do the math with/without compund interest*.
#
# The function should have following mandatory input parameters:
# - **base_captial**
# - **yearly_interest**
#
# and returns the **final_amount** (Kn)
#
# Additionally try to catch potential user input errors for the mandatory input parameters with try/except & if/else checks. For example:
# - make sure that input numbers are positive.
# - so checking for datatype
# - Write down some ideas, what input errors could occour?
#
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercise#2: Create your first Python module
#
# Write following code to a file called 'functions.py' in your current work directory.
#
#
#
# ```
# def greeting(name):
#   print("Hello, " + name)
#
# def print_sum(x,y):
#     print(sum([x,y]))
#
# def print_end():
#     print('Ende')
# ```

# %%
from pathlib import Path
Path.cwd()
# Out:
# PosixPath('/content')

# %%
import functions
#if we change something in our 'functions.py' after we imported it 
#for the first time as submodule, the Notebook will not import the changes.
#For this we need the two following magic commands
# %load_ext autoreload
# %autoreload 2

# %%
functions.greeting('Mathias')
# Out:
# Hello, Mathias

# %%
functions.greeting('Harald')
# Out:
# Hello, Harald

# %%
functions.print_sum(10,20)
# Out:
# 30

# %%
functions.print_end()
# Out:
# Ende

# %%
from functions import *

# %%
print_end()
# Out:
# Ende

# %%
greeting('susi')
# Out:
# Hello, susi

# %% [markdown]
# ## Exercise#3 Pandas DF  Plot

# %% [markdown]
# You have 20 minutes to solve the below exercises and produce the expected outputs. One student will be choosen randomly to present his/hers results.

# %% [markdown]
# * Import the sample dataset **california_housing_test.csv** to a pandas dataframe.
# * Print the head, columns, and the shape of the DF to assess the dataset
# * Produce the three follwing plots using the *plotly* package
#   - a [histogram](https://plotly.com/python/histograms/) of column "median_income" with the title "California Housing - Median Income"
#   - a [scatterplot](https://plotly.com/python/line-and-scatter/) of "median_income" & "median_house_value" showing a linear trendline
#   - a scatterplot of "median_income" & "median_house_value" showing a logarithmic trendline
#
#   **Hint**
#   To use Plottly as ploting backend for pandas (instead of standard matplotlib) use following code
#
#
# ```
# import pandas as pd
# pd.options.plotting.backend = "plotly"
# ```
