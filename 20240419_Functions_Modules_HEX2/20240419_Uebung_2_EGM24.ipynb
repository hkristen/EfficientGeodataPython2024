# %% [markdown]
# ## Homework #2- Have fun with CSV files
#
# CSV file are great, we need them all the time -> so let's practice handling them :)
#
# ```
# Extract the content of the provided "sample_data.zip" to a folder in your workspace. It contains all the data we'll need for this HEX
# ```
#
#
# 1. Either provide a Flowchart OR Pseudocode for your solution (1)
#
# 2. Write a function that takes a *string with a path* OR *pathlib object* as input and returns a list, that contains all paths to the individual **CSV files** as PATH objects named *csv_lst_pths*. (2)
#
# 3. Write a function that takes above list as input. It should return a list of Pandas Objects, only containing the first 100 rows of each file, called *csv_lst_pd_short* (2)
#
# 4. Write a function that adds a new column called *edited* to a Pandas dataframe and fill it with the current time in your timezone, in this format:
# ```
# 09:55:22
# ```
# The return of the function is the changed Pandas dataframe. (2)
#
#
# 5. Apply the function created in the above point 4 to all Pandas dataframes in *csv_lst_pd_short*.
# Then write a function that writes every Pandas dataframe in the list **csv_lst_pd_short** as a CSV file to the original folder. The new filename should consist of the original filename with '_short.csv' added to it. (3)
#
# ```
# #Example file name
# 'mnist_test_short.csv'
# ```
